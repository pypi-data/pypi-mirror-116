# %% [markdown]
# # Vital Signs
#
# > Scripts to create our annual, publicly-available, community-focused datasets; for Baltimore City.

# %% [markdown]
# <img align="right" src="https://raw.githubusercontent.com/bniajfi/bniajfi/main/bnia_logo_new.png" height="160px" width="auto">
#
# <h2 align="left"><img src="https://raw.githubusercontent.com/sidbelbase/sidbelbase/master/wave.gif" width="30px">Hi! We are <a href="https://bniajfi.org/">BNIA-JFI</a>.</h2>
#
# This package was made to help with data handling.
#
# __Included__
# - Functions built and used by BNIA for day to day tasks.
# - Made to be shared via IPYNB/ Google Colab notebooks with in-built examples using 100% publicly accessible data & links.
# - Online [documentation](https://bniajfi.org/VitalSigns/)  and [PyPi](https://pypi.org/project/VitalSigns/) libraries created from the notebooks.

# %% [markdown]
# [TOC](https://github.com/bniajfi)

# %% [markdown]
# [VitalSigns](https://bniajfi.org/VitalSigns/) uses functions found in our [Dataplay](https://bniajfi.org/dataplay/)  Module and vice-versa.

# %% [markdown]
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/bnia/VitalSigns/main?filepath=%2Fnotebooks%2Findex.ipynb)
# [![Binder](https://pete88b.github.io/fastpages/assets/badges/colab.svg)](https://colab.research.google.com/github/bnia/VitalSigns/blob/main/notebooks/index.ipynb)
# [![Binder](https://pete88b.github.io/fastpages/assets/badges/github.svg)](https://github.com/bnia/VitalSigns/tree/main/notebooks/index.ipynb)
# [![Open Source Love svg3](https://badges.frapsoft.com/os/v3/open-source.svg?v=103)](https://github.com/ellerbrock/open-source-badges/)
#
# [![NPM License](https://img.shields.io/npm/l/all-contributors.svg?style=flat)](https://github.com/bnia/VitalSigns/blob/main/LICENSE)
# [![Active](http://img.shields.io/badge/Status-Active-green.svg)](https://bnia.github.io)
# [![Python Versions](https://img.shields.io/pypi/pyversions/VitalSigns.svg)](https://pypi.python.org/pypi/VitalSigns/)
# [![GitHub last commit](https://img.shields.io/github/last-commit/bnia/VitalSigns.svg?style=flat)]()
#
# [![GitHub stars](https://img.shields.io/github/stars/bnia/VitalSigns.svg?style=social&label=Star)](https://github.com/bnia/VitalSigns)
# [![GitHub watchers](https://img.shields.io/github/watchers/bnia/VitalSigns.svg?style=social&label=Watch)](https://github.com/bnia/VitalSigns)
# [![GitHub forks](https://img.shields.io/github/forks/bnia/VitalSigns.svg?style=social&label=Fork)](https://github.com/bnia/VitalSigns)
# [![GitHub followers](https://img.shields.io/github/followers/bnia.svg?style=social&label=Follow)](https://github.com/bnia/VitalSigns)
#
# [![Tweet](https://img.shields.io/twitter/url/https/github.com/bnia/VitalSigns.svg?style=social)](https://twitter.com/intent/tweet?text=Check%20out%20this%20%E2%9C%A8%20colab%20by%20@bniajfi%20https://github.com/bnia/VitalSigns%20%F0%9F%A4%97)
# [![Twitter Follow](https://img.shields.io/twitter/follow/bniajfi.svg?style=social)](https://twitter.com/bniajfi)

# %% [markdown]
# ## ACS Scripts

# %% [markdown]
# These scripts will download and clean ACS data for Baltimore and then construct indicators from the data.
#
# AcsDownload.ipynb
# Mount notebook to google drive
# Read in ACS Meta Data from XLSX and the crosswalk data from a csv
# Add path to python script that performs download function
# Enter a year and Run the download function for every record in XLSX sheet
# For each dataset, remove columnID’s then save it as Raw
# Then, Append Community Names using a crosswalk and save again in as Clean
#
#
# AcsIndicators.ipynb
# Mount notebook to google drive
# Read in ACS Meta Data from XLSX
# Prepare the Compare Historic Data
# - For Each Indicator
# - Grab its Meta Data
# - If the Indicator is valid for the year, and uses ACS Data, and method exists
# - retrieve the Python ACS indicator
# - Put Baltimore City at the bottom of the list
# - Write the results back into the XL dataframe
# - Save the Dataset
# - drop columns with any empty values
# - Save the Data xlsx
# Do comparison to historic year if exists. Write xlsx.

# %% [markdown]
# ## Usage Instructions

# %% [markdown]
# ### Install the Package

# %% [markdown]
# The code is on <a href="https://pypi.org/project/test-template/">PyPI</a> so you can install the scripts as a python library using the command:
#
# `!pip install VitalSigns geopandas`

# %% [markdown]
# > Important: Contributers should follow the maintanance instructions and will not need to run this step.
# >
# > Their modules will be retrieved from the VitalSigns-GDrive repo they have mounted into their Colabs Enviornment.

# %%
#hide 
# !pip install dataplay geopandas #VitalSigns

# %% [markdown]
# Then...

# %% [markdown]
# ### Import Modules

# %% [markdown]
# 1) Import the installed module into your code:
# ```
# from VitalSigns.acsDownload import retrieve_acs_data
# ```
# 2) use it
# ```
# retrieve_acs_data(state, county, tract, tableId, year, saveAcs)
# ```
# Now you could do something like merge it to another dataset!
# ```
# from dataplay.merge import mergeDatasets
# mergeDatasets(left_ds=False, right_ds=False, crosswalk_ds=False,  use_crosswalk = True, left_col=False, right_col=False, crosswalk_left_col = False, crosswalk_right_col = False, merge_how=False, interactive=True)
# ```

# %% [markdown]
# ### Getting Help

# %% [markdown]
# You can get information on the package by using the help command.

# %% [markdown]
# Here we look at the package's modules:

# %%
import VitalSigns
help(VitalSigns)

# %% [markdown]
# Lets take a look at what functions the geoms module provides:

# %%
import VitalSigns.acsDownload
help(VitalSigns.acsDownload)
# Out:
# Help on module VitalSigns.acsDownload in VitalSigns:
#
# NAME
#     VitalSigns.acsDownload - # AUTOGENERATED! DO NOT EDIT! File to edit: notebooks/90_ACS_Explore_and_Download.ipynb (unless otherwise specified).
#
# FUNCTIONS
#     retrieve_acs_data(state, county, tract, tableId, year, save)
#
# DATA
#     __all__ = ['retrieve_acs_data']
#
# FILE
#     /content/drive/My Drive/Software Development Documents/VitalSigns/VitalSigns/acsDownload.py

# %% [markdown]
# And here we can look at an individual function and what it expects:

# %%
import VitalSigns.acsDownload
help(VitalSigns.acsDownload.retrieve_acs_data)
# Out:
# Help on function retrieve_acs_data in module VitalSigns.acsDownload:
#
# retrieve_acs_data(state, county, tract, tableId, year, save)

# %% [markdown]
# ## Examples

# %% [markdown]
# So heres an example:
#
#
# Import your modules

# %%
from VitalSigns.acsDownload import retrieve_acs_data

# %%
#hide
import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 6)
pd.set_option('display.width', 10)
pd.set_option('max_colwidth', 20)

# %% [markdown]
# Read in some data

# %% [markdown]
# Define our download parameters.
#
# More information on these parameters can be found in the tutorials!

# %%
# Our download function will use Baltimore City's tract, county and state as internal paramters
# Change these values in the cell below using different geographic reference codes will change those parameters
tract = '*'
county = '510'
state = '24'

# Specify the download parameters the function will receieve here
tableId = 'B19001'
year = '17'
saveAcs = False

# %% [markdown]
# And download the Baltimore City ACS data using the imported VitalSigns library.

# %%
df = retrieve_acs_data(state, county, tract, tableId, year, saveAcs)
df.head(1)
# Out:
# Number of Columns 17
#                       B19001_001E_Total  \
# NAME
# Census Tract 2710.02               1510
#
#                       B19001_002E_Total_Less_than_$10,000  \
# NAME
# Census Tract 2710.02                  209
#
#                       B19001_003E_Total_$10,000_to_$14,999  \
# NAME
# Census Tract 2710.02                   73
#
#                       ...  \
# NAME                  ...
# Census Tract 2710.02  ...
#
#                       state  \
# NAME
# Census Tract 2710.02     24
#
#                       county  \
# NAME
# Census Tract 2710.02     510
#
#                        tract
# NAME
# Census Tract 2710.02  271002
#
# [1 rows x 20 columns]

# %% [markdown]
# From there, you can go on to do even greater things using our [dataplay](https://github.com/BNIA/dataplay) library. Like these visuals:

# %%
ls
# Out:
# build/              docs/         MANIFEST.in   setup.py
# CONTRIBUTING.md     index_files/  notebooks/    VitalSigns/
# dist/               LICENSE       README.md     VitalSigns.egg-info/
# docker-compose.yml  Makefile      settings.ini

# %%
from VitalSigns.create import createAcsIndicator, mhhi 
mergeUrl = 'https://raw.githubusercontent.com/bniajfi/bniajfi/main/CSA-to-Tract-2010.csv'
merge_left_col = 'tract'
merge_right_col= 'TRACTCE10' 
merge_how = 'outer'

groupBy = 'CSA2010'

method = mhhi
aggMethod = 'sum'
columnsToInclude = []


createAcsIndicator(state, county, tract, year, tableId, saveAcs,
                    mergeUrl, merge_left_col, merge_right_col, merge_how, groupBy,
                    aggMethod, method, columnsToInclude, finalFileName=False).head(1)
# Out:
# Number of Columns 17
# Table: B19001, Year: 17 imported.
# Index(['TRACTCE10', 'GEOID10', 'CSA2010'], dtype='object')
# Merge file imported
# Both are now merged.
# Aggregating...
# Aggregated
# Creating Indicator
# INCLUDING COLUMN(s):['tract']
# Indicator Created
#                       B19001_002E_Total_Less_than_$10,000  B19001_003E_Total_$10,000_to_$14,999  B19001_004E_Total_$15,000_to_$19,999  B19001_005E_Total_$20,000_to_$24,999  B19001_006E_Total_$25,000_to_$29,999  B19001_007E_Total_$30,000_to_$34,999  B19001_008E_Total_$35,000_to_$39,999  B19001_009E_Total_$40,000_to_$44,999  B19001_010E_Total_$45,000_to_$49,999  B19001_011E_Total_$50,000_to_$59,999  B19001_012E_Total_$60,000_to_$74,999  B19001_013E_Total_$75,000_to_$99,999  B19001_014E_Total_$100,000_to_$124,999  B19001_015E_Total_$125,000_to_$149,999  B19001_016E_Total_$150,000_to_$199,999  B19001_017E_Total_$200,000_or_more  midpoint midpoint_index midpoint_index_value midpoint_index_lower midpoint_index_range midpoint_index_minus_one_cumulative_sum     final    tract
# CSA2010
# Allendale/Irvingt...                  739                                 1246                                  1656                                  2016                                  2357                                  2667                                  3099                                  3460                                  3723                                  4316                                  5046                                  5619                                  5847                                    5962                                    6050                                    6111                   3055.5              6                  432                35000                 4999                 2667                     39495.63  1333309

# %% [markdown]
# <h2 align="left">Have Fun!</h2>
# <img src="https://bniajfi.org/images/mermaid/vitalSignsCorrelations.png" width="500px">
# <img src="https://bniajfi.org/images/mermaid/vitalSignsGif.gif" width="500px">

# %% [markdown]
# ## MISC

# %% [markdown]
# This section is not definite but provides a good idea of how our scripts are made.

# %% [markdown]
# __Basic Indicator Creation Outline__
# - ? Count = 1
# - Create the num and denom
# - filter num denom
# - ? sum/ median = ungrouped.median
# - group by csa
# - ? bcity = median or sum
# - perform the calculation
# - compare years

# %% [markdown]
# __Miscellaneous things I should have for every notebook__
# - Module/filenames need to be fixed.
# - RB Intel has the best prelim analysis script. The others are messed up a bit?
# - include links indicator Esri and Bnia pages details on category, name, description, years
# - Don’t drop columns at end, but keep selected at beginning.
# - Merge on CSA for ordering
# - Bcity Median gets calculated before aggregation. Appended after
# - Add Years in header. Use denom and numerator as var names.
# - Code to compare past years

# %% [markdown]
# ## FOR CONTRIBUTERS

# %% [markdown]
# ### Dev Instructions

# %% [markdown]
# From a local copy of the git repo:
# 0. __Clone__ the repo local onto GDrive
#   - Via Direct-DL&Drive-Upload or Colab/Terminal/Git
#   - `git clone https://github.com/BNIA/VitalSigns.git`
# 1. __Update__ the the IPYNB
#   - From the GDrive VitalSigns folder via Colabs
# 2. __Build__ the new libraries from these NBs
#   - Using this *index.ipynb*
#   - - Mount the Colabs Enviornment (and navigate to) the GDrive VitalSigns folder
#   - - run `!nbdev_build_lib` to build .py modules.
# 3. __Test__ the Library/ Modules
#   - Using the same runtime as step 2's *index.ipynb*.
#   - - Do not install the module from PyPi (if published) and then...
#   - - Import your module (
#   from your VitalSigns/VitalSigns)
#   - - If everything runs properly, go to step 5.
# 4. __Edit__ modules directly
#   - Within the same runtime as step 2/3's *index.ipynb*...
#   - - Locate the VitalSigns/VitalSigns using the colab file nav
#   - - double-click the .py modules in the file nav to open them in an in-browser editor
#   - Make changes and return to step 3 with the following caveat:
#   - - Use the hot module reloading to ensure updates are auto-re-imported
#   - - `%load_ext autoreload %autoreload 2`
#   - Then when finished, persist the changes from the .py modules back to the .ipynb docs
#   - - via `!nbdev_update_lib` and `!relimport2name`
# 5. **Create** Docs, **Push** to Github, and **Publish** to PyPI
#   - All done via [nbdev](https://nbdev.fast.ai/)
#   - Find more notes I made on that here: [dataplay](https://github.com/bnia/dataplay) > nbdev [notes](https://bnia.github.io/datalabs/nbdev/index.html)
#   - `!nbdev_build_docs --force_all True --mk_readme True `
#   - `!git commit -m ...`
#   - `%%capture ! pip install twine`
#   - `!nbdev_bump_version`
#   - `! make pypi`

# %%
# https://nbdev.fast.ai/tutorial.html#Set-up-prerequisites
# settings.ini > requirements = fastcore>=1.0.5 torchvision<0.7
# https://nbdev.fast.ai/tutorial.html#View-docs-locally
# console_scripts = nbdev_build_lib=nbdev.cli:nbdev_build_lib
# https://nbdev.fast.ai/search

# %% [markdown]
# ### Dev Scripts

# %%
#hide
# !pip install nbdev
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My Drive/'Software Development Documents'/
# %cd VitalSigns 
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/Software Development Documents
# /content/drive/My Drive/Software Development Documents/VitalSigns
# build/              docs/         MANIFEST.in   setup.py
# CONTRIBUTING.md     index_files/  notebooks/    VitalSigns/
# dist/               LICENSE       README.md     VitalSigns.egg-info/
# docker-compose.yml  Makefile      settings.ini

# %%
cd ../dataplay
# Out:
# /content/drive/My Drive/Software Development Documents/dataplay

# %%
! nbdev_build_lib
# Out:
# Converted 00_core.ipynb.
# Converted 01_Close Crawl.ipynb.
# Converted 02_TidyAddr.ipynb.
# Converted 03_convertVSSheetForWPUpload.ipynb.
# Converted 04_Create_Acs_Indicators_Original.ipynb.
# Converted 05_Create_Acs_Indicators.ipynb.
# Converted 90_ACS_Explore_and_Download.ipynb.
# Converted 91_Acs_Download_VS.ipynb.
# Converted 92_Acs_Create_and_Compare_VS.ipynb.
# Converted BCPSS_Schools.ipynb.
# Converted BPD_P1.ipynb.
# Converted BPD_P1_Visualizations.ipynb.
# Converted Bidbalt_TaxSale_Taxlien.ipynb.
# Converted CitiStat_Dirtyst_Clogged.ipynb.
# Converted CityFinance_histaxhometaxowntax.ipynb.
# Converted City_Liquor_Board_Permits.ipynb.
# Converted DHR_SNAP_TANF_Create.ipynb.
# Converted EnochPratt_Libcard.ipynb.
# Converted FARES_Salpr_Shome.ipynb.
# Converted FDIC_Banks.ipynb.
# Converted HUD.ipynb.
# Converted Infousa.ipynb.
# Converted Mdprop_Permits_Fore_Vac Vio.ipynb.
# Converted RBIntel.ipynb.
# Converted TidyAddr_EnochPratt.ipynb.
# Converted TreeBaltimore_TreePlnt.ipynb.
# Converted index.ipynb.

# %%
#hide
# this will reload imported modules whenever the .py file changes. 
# whenever the .py file changes via nbdev_build_lib or _update_lib. 
# %load_ext autoreload
# %autoreload 2

# %%
ls
# Out:
# sample_data/

# %%
#hide
# !nbdev_build_lib
# !nbdev_build_docs --force_all True --mk_readme True
# !nbdev_nb2md 'notebooks/index.ipynb' > README.md

# %%
#hide
# https://nbdev.fast.ai/tutorial.html#Add-in-notebook-export-cell
# https://nbdev.fast.ai/sync#nbdev_update_lib
# first. builds the .py files from from .ipynbs
# ____ !nbdev_build_lib #  --fname filename.ipynb
# second. Push .pu changes back to their original .ipynbs
# ____ !nbdev_update_lib 
# sometimes. Update .ipynb import statements if the .py filename.classname changes. 
# ____ !relimport2name
# nbdev_build_docs builds the documentation from the notebooks
# ____ !nbdev_build_docs --force_all True --mk_readme True

# %%
#hide
"""
! git add *
! git config --global user.name "bnia"
! git config --global user.email "charles.karpati@gmail.com"
! git commit -m "initial commit"
# git push -f origin master 
! git push -u ORIGIN main
"""

# %%
#hide
! pip install twine
# ! nbdev_bump_version
! make pypi
# Out:
# Requirement already satisfied: twine in /usr/local/lib/python3.7/dist-packages (3.4.2)
# Requirement already satisfied: readme-renderer>=21.0 in /usr/local/lib/python3.7/dist-packages (from twine) (29.0)
# Requirement already satisfied: tqdm>=4.14 in /usr/local/lib/python3.7/dist-packages (from twine) (4.41.1)
# Requirement already satisfied: keyring>=15.1 in /usr/local/lib/python3.7/dist-packages (from twine) (23.0.1)
# Requirement already satisfied: pkginfo>=1.4.2 in /usr/local/lib/python3.7/dist-packages (from twine) (1.7.1)
# Requirement already satisfied: rfc3986>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from twine) (1.5.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.7/dist-packages (from twine) (2.23.0)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from twine) (4.6.1)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from twine) (0.9.1)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.7/dist-packages (from twine) (0.4.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->twine) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->twine) (3.5.0)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.7/dist-packages (from keyring>=15.1->twine) (3.3.1)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.7/dist-packages (from keyring>=15.1->twine) (0.7.1)
# Requirement already satisfied: docutils>=0.13.1 in /usr/local/lib/python3.7/dist-packages (from readme-renderer>=21.0->twine) (0.17.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from readme-renderer>=21.0->twine) (1.15.0)
# Requirement already satisfied: Pygments>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from readme-renderer>=21.0->twine) (2.6.1)
# Requirement already satisfied: bleach>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from readme-renderer>=21.0->twine) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine) (21.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=2.1.0->readme-renderer>=21.0->twine) (0.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->twine) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->twine) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->twine) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.20->twine) (2021.5.30)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.7/dist-packages (from SecretStorage>=3.2->keyring>=15.1->twine) (3.4.7)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.1->twine) (2.20)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bleach>=2.1.0->readme-renderer>=21.0->twine) (2.4.7)
# rm -rf dist
# python setup.py sdist bdist_wheel
# running sdist
# running egg_info
# writing VitalSigns.egg-info/PKG-INFO
# writing dependency_links to VitalSigns.egg-info/dependency_links.txt
# writing entry points to VitalSigns.egg-info/entry_points.txt
# writing requirements to VitalSigns.egg-info/requires.txt
# writing top-level names to VitalSigns.egg-info/top_level.txt
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '__pycache__' found under directory '*'
# adding license file 'LICENSE'
# writing manifest file 'VitalSigns.egg-info/SOURCES.txt'
# running check
# creating VitalSigns-0.0.7
# creating VitalSigns-0.0.7/VitalSigns
# creating VitalSigns-0.0.7/VitalSigns.egg-info
# creating VitalSigns-0.0.7/notebooks
# copying files to VitalSigns-0.0.7...
# copying CONTRIBUTING.md -> VitalSigns-0.0.7
# copying LICENSE -> VitalSigns-0.0.7
# copying MANIFEST.in -> VitalSigns-0.0.7
# copying Makefile -> VitalSigns-0.0.7
# copying README.md -> VitalSigns-0.0.7
# copying docker-compose.yml -> VitalSigns-0.0.7
# copying settings.ini -> VitalSigns-0.0.7
# copying setup.py -> VitalSigns-0.0.7
# copying VitalSigns/BCPSS.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/HUD.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/__init__.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/_nbdev.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/acsDownload.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/bidbaltimore.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/bpd.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/citistat.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/cityfinance.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/closecrawl.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/create.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/dhr.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/enoch.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/fares.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/fdic.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/indicators.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/infousa.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/liquor.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/mdprop.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/rbintel.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/tidyaddr.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/treebaltimore.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns/utils.py -> VitalSigns-0.0.7/VitalSigns
# copying VitalSigns.egg-info/PKG-INFO -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/SOURCES.txt -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/dependency_links.txt -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/entry_points.txt -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/not-zip-safe -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/requires.txt -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying VitalSigns.egg-info/top_level.txt -> VitalSigns-0.0.7/VitalSigns.egg-info
# copying notebooks/00_core.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/01_Close Crawl.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/02_TidyAddr.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/03_convertVSSheetForWPUpload.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/04_Create_Acs_Indicators_Original.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/05_Create_Acs_Indicators.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/90_ACS_Explore_and_Download.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/BCPSS_Schools.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/BPD_P1.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/BPD_P1_Visualizations.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/Bidbalt_TaxSale_Taxlien.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/CitiStat_Dirtyst_Clogged.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/CityFinance_histaxhometaxowntax.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/City_Liquor_Board_Permits.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/DHR_SNAP_TANF_Create.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/EnochPratt_Libcard.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/FARES_Salpr_Shome.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/FDIC_Banks.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/HUD.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/Infousa.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/Mdprop_Permits_Fore_Vac Vio.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/RBIntel.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/TidyAddr_EnochPratt.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/TreeBaltimore_TreePlnt.ipynb -> VitalSigns-0.0.7/notebooks
# copying notebooks/index.ipynb -> VitalSigns-0.0.7/notebooks
# Writing VitalSigns-0.0.7/setup.cfg
# creating dist
# Creating tar archive
# removing 'VitalSigns-0.0.7' (and everything under it)
# running bdist_wheel
# running build
# running build_py
# installing to build/bdist.linux-x86_64/wheel
# running install
# running install_lib
# creating build/bdist.linux-x86_64/wheel
# creating build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/BCPSS.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/indicators.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/liquor.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/dhr.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/cityfinance.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/utils.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/tidyaddr.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/acsDownload.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/citistat.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/closecrawl.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/rbintel.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/HUD.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/create.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/treebaltimore.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/fdic.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/_nbdev.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/infousa.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/fares.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/enoch.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/mdprop.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/bpd.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/bidbaltimore.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# copying build/lib/VitalSigns/__init__.py -> build/bdist.linux-x86_64/wheel/VitalSigns
# running install_egg_info
# Copying VitalSigns.egg-info to build/bdist.linux-x86_64/wheel/VitalSigns-0.0.7-py3.7.egg-info
# running install_scripts
# adding license file "LICENSE" (matched pattern "LICEN[CS]E*")
# creating build/bdist.linux-x86_64/wheel/VitalSigns-0.0.7.dist-info/WHEEL
# creating 'dist/VitalSigns-0.0.7-py3-none-any.whl' and adding 'build/bdist.linux-x86_64/wheel' to it
# adding 'VitalSigns/BCPSS.py'
# adding 'VitalSigns/HUD.py'
# adding 'VitalSigns/__init__.py'
# adding 'VitalSigns/_nbdev.py'
# adding 'VitalSigns/acsDownload.py'
# adding 'VitalSigns/bidbaltimore.py'
# adding 'VitalSigns/bpd.py'
# adding 'VitalSigns/citistat.py'
# adding 'VitalSigns/cityfinance.py'
# adding 'VitalSigns/closecrawl.py'
# adding 'VitalSigns/create.py'
# adding 'VitalSigns/dhr.py'
# adding 'VitalSigns/enoch.py'
# adding 'VitalSigns/fares.py'
# adding 'VitalSigns/fdic.py'
# adding 'VitalSigns/indicators.py'
# adding 'VitalSigns/infousa.py'
# adding 'VitalSigns/liquor.py'
# adding 'VitalSigns/mdprop.py'
# adding 'VitalSigns/rbintel.py'
# adding 'VitalSigns/tidyaddr.py'
# adding 'VitalSigns/treebaltimore.py'
# adding 'VitalSigns/utils.py'
# adding 'VitalSigns-0.0.7.dist-info/LICENSE'
# adding 'VitalSigns-0.0.7.dist-info/METADATA'
# adding 'VitalSigns-0.0.7.dist-info/WHEEL'
# adding 'VitalSigns-0.0.7.dist-info/entry_points.txt'
# adding 'VitalSigns-0.0.7.dist-info/top_level.txt'
# adding 'VitalSigns-0.0.7.dist-info/RECORD'
# removing build/bdist.linux-x86_64/wheel
# twine upload --repository pypi dist/*
# Uploading distributions to https://upload.pypi.org/legacy/
# Enter your username: Traceback (most recent call last):
#   File "/usr/local/bin/twine", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/twine/__main__.py", line 28, in main
#     result = cli.dispatch(sys.argv[1:])
#   File "/usr/local/lib/python3.7/dist-packages/twine/cli.py", line 71, in dispatch
#     return main(args.args)
#   File "/usr/local/lib/python3.7/dist-packages/twine/commands/upload.py", line 154, in main
#     return upload(upload_settings, parsed_args.dists)
#   File "/usr/local/lib/python3.7/dist-packages/twine/commands/upload.py", line 91, in upload
#     repository = upload_settings.create_repository()
#   File "/usr/local/lib/python3.7/dist-packages/twine/settings.py", line 345, in create_repository
#     self.username,
#   File "/usr/local/lib/python3.7/dist-packages/twine/settings.py", line 146, in username
#     return cast(Optional[str], self.auth.username)
#   File "/usr/local/lib/python3.7/dist-packages/twine/auth.py", line 39, in username
#     prompt_strategy=self.username_from_keyring_or_prompt,
#   File "/usr/local/lib/python3.7/dist-packages/twine/utils.py", line 240, in get_userpass_value
#     return prompt_strategy()
#   File "/usr/local/lib/python3.7/dist-packages/twine/auth.py", line 84, in username_from_keyring_or_prompt
#     return self.prompt("username", input)
#   File "/usr/local/lib/python3.7/dist-packages/twine/auth.py", line 95, in prompt
#     return how(f"Enter your {what}: ")
# KeyboardInterrupt
# Makefile:31: recipe for target 'pypi' failed
# make: *** [pypi] Error 1
# ^C
