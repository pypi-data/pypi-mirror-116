# %%
import os,glob
t = glob.glob('*')
if 'tmp' in t:
    os.system('rm -R tmp')
os.system('mkdir tmp')
# Out:
# 0

# %%
# ##### Example: read Google sheet
# from rolling_snapshot_proposal_editor.googlesheetreader import GoogleSheetReader
# CREDENTIAL = '/Users/kbhirombhakdi/Downloads/client_secret_560341155382-s324iuntpd9djf1avojfh6u1e4shu012.apps.googleusercontent.com.json'
# SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']
# SHEETID = '1eR2AQkKx9RytN2Pj7cwqeYJjLh8IEC4wXx96Lq2McGI'
# RANGENAME = 'Active'
# sheet = GoogleSheetReader(scopes=SCOPES,sheetid=SHEETID,rangename=RANGENAME,credential=CREDENTIAL)
# sheet_df = sheet.df

# %%
import pandas as pd
from rolling_snapshot_proposal_editor.templatehandler import TemplateHandler
from rolling_snapshot_proposal_editor.update_targetlist_from_sheet import update_targetlist_from_sheet
from rolling_snapshot_proposal_editor.update_visits_from_sheet import update_visits_from_sheet
propfile = TemplateHandler().templatedict['demo_propfile']
outname = './tmp/test.prop'
sheet_df = pd.read_csv(TemplateHandler().templatedict['demo_sheet'])
update_targetlist_from_sheet(sheet_df,propfile,outname)
update_visits_from_sheet(sheet_df,outname,outname)
# Out:
# Use self.templatedict to see available template files. Use, e.g., self.read(templatefile='fixed_target.json') to read.
#
# Use self.templatedict to see available template files. Use, e.g., self.read(templatefile='fixed_target.json') to read.
#
# Start update_targetlist_from_sheet ...
#
# Grabbing active target list ...
#
# Grabing old target list ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Comparing lists ...
#
# Removing target numbers [True, True, True, True, True, True, True, True, True] ...
#
# Use self.templatedict to see available template files. Use, e.g., self.read(templatefile='fixed_target.json') to read.
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 1, target name ZTF21ABJYIIW ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A1...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A2...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A3...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A4...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A5...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A6...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A6 ...
#
# Finish.
# /Users/kbhirombhakdi/anaconda3/envs/astroconda202104/lib/python3.7/site-packages/rolling_snapshot_proposal_editor/update_targetlist_from_sheet.py:32: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   tt = True if t not in activelist else False
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A7...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A8...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number A9...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing A9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number AA...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing AA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number AB...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing AB ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number AC...
#
# Line start 366
#
# Line stop 444
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing AC ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 2, target name ZTF21AANXHJV ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B1...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B2...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B3...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B4...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B5...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B6...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B7...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B8...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number B9...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing B9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number BA...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing BA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number BB...
#
# Line start 347
#
# Line stop 431
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing BB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 3, target name SN2021UCX ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C1...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C2...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C3...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C4...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C5...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C6...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C7...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C8...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number C9...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing C9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number CA...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing CA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number CB...
#
# Line start 328
#
# Line stop 412
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing CB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 4, target name ZTF21ABMJIVK ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D1...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D2...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D3...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D4...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D5...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D6...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D7...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D8...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number D9...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing D9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number DA...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing DA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number DB...
#
# Line start 309
#
# Line stop 393
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing DB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 5, target name ZTF21ABLVZHP ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E1...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E2...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E3...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E4...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E5...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E6...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E7...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E8...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number E9...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing E9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number EA...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing EA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number EB...
#
# Line start 290
#
# Line stop 374
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing EB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 6, target name ZTF21ABLWEHD ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F1...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F2...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F3...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F4...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F5...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F6...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F7...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F8...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number F9...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing F9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number FA...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing FA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number FB...
#
# Line start 271
#
# Line stop 355
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing FB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 7, target name ZTF21ABKGGOA ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G1...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G2...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G3...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G4...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G5...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G6...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G7...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G8...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number G9...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing G9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number GA...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing GA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number GB...
#
# Line start 252
#
# Line stop 336
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing GB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 8, target name ZTF21ABKDPNW ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H1...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H2...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H3...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H4...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H5...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H6...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H7...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H8...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number H9...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing H9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number HA...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing HA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number HB...
#
# Line start 233
#
# Line stop 317
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing HB ...
#
# Finish.
#
# Finish ...
#
# load json_template ...
#
# read propfile ...
#
# read target name ...
#
# Getting a list of target numbers ...
#
# Read propfile ...
#
# Search keyword: 'Target_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# find line number ...
#
# 187
# remove ...
#
# Creating ./tmp/test.prop ...
#
# Removing visits associating with target number 9, target name ZTF21ABCGNQN ...
#
# Getting a list of visit numbers ...
#
# Read propfile ...
#
# Search keyword: 'Visit_Number:'
#
# Return profile ...
#
# Matching with target name ...
#
# Preparing output ...
#
# Finish.
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I1...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I1 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I2...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I2 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I3...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I3 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I4...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I4 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I5...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I5 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I6...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I6 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I7...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I7 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I8...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I8 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number I9...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing I9 ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number IA...
#
# Line start 214
#
# Line stop 298
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing IA ...
#
# Finish.
#
# Reading ./tmp/test.prop ...
#
# Listing visits ...
#
# Finish ...
#
# Finding line indices for visit number IB...
#
# Line start 214
#
# Line stop 397 at EOF
#
# Grabbing the original file ...
#
# Creating ./tmp/test.prop ...
#
# Removing IB ...
#
# Finish.
#
# Finish ...
#
# Use self.templatedict to see available template files. Use, e.g., self.read(templatefile='fixed_target.json') to read.
#
# Grabbing target number 99 ...
#
# Preparing RADEC string ...
#
# Finalizing ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-5182dbb8b583> in <module>
#       6 outname = './tmp/test.prop'
#       7 sheet_df = pd.read_csv(TemplateHandler().templatedict['demo_sheet'])
# ----> 8 update_targetlist_from_sheet(sheet_df,propfile,outname)
#       9 update_visits_from_sheet(sheet_df,outname,outname)
#
# ~/anaconda3/envs/astroconda202104/lib/python3.7/site-packages/rolling_snapshot_proposal_editor/update_targetlist_from_sheet.py in update_targetlist_from_sheet(sheet_df, propfile, outname, remove_visits, verbal)
#      42         if status=='N':
#      43             targetnumber = targetnumberlist[ii]
# ---> 44             targetinfo = prepare_targetinfo(spreadsheet=sheet_df,read_spreadsheet_csv=False,targetnumber=targetnumber,json_template=TemplateHandler().templatedict['fixed_target'])
#      45             add_fixed_target(propfile=outname,targetinfo=targetinfo,outname=outname,line_index=None)
#      46             print('Added target number {0} ... \n'.format(targetnumber))
#
# ~/anaconda3/envs/astroconda202104/lib/python3.7/site-packages/rolling_snapshot_proposal_editor/prepare_targetinfo.py in prepare_targetinfo(spreadsheet, read_spreadsheet_csv, targetnumber, json_template)
#      32     targetinfo = json.loads(f.readlines()[0])
#      33     f.close()
# ---> 34     targetinfo['Target_Number'] += targetnumber
#      35     targetinfo['Target_Name'] += targetname
#      36     if targettype == 'TDE':
#
# TypeError: can only concatenate str (not "numpy.int64") to str

# %%
# %debug
# Out:
# > /Users/kbhirombhakdi/anaconda3/envs/astroconda202104/lib/python3.7/site-packages/rolling_snapshot_proposal_editor/prepare_targetinfo.py(34)prepare_targetinfo()
#      32     targetinfo = json.loads(f.readlines()[0])
#      33     f.close()
# ---> 34     targetinfo['Target_Number'] += targetnumber
#      35     targetinfo['Target_Name'] += targetname
#      36     if targettype == 'TDE':
# ipdb>  targetnumber
# 99
# ipdb>  targetinfo['Target_Number']
# '  Target_Number: '
# ipdb>  targetinfo['Target_Number'] += targetnumber
# *** TypeError: can only concatenate str (not "numpy.int64") to str
# ipdb>  type(targetnumber)
# <class 'numpy.int64'>
